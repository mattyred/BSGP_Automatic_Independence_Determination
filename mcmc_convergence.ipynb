# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mcmc_results = np.load('results/run-0003/boston_mcmc_results.npz')
mcmc_mean_samples = mcmc_results['mcmc_samples_mean']
mcmc_var_samples = mcmc_results['mcmc_samples_var']
mcmc_logps_samples = mcmc_results['mcmc_samples_logps']

# %%
sns.lineplot(x=np.arange(0,256,1), y=mcmc_mean_samples[0])
# Out:
# <Axes: >
